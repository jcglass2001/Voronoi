# %% [markdown]
# #Setup

# %%
# !cd /usr/local/cuda/samples/1_Utilities/deviceQuery && sudo make && ./deviceQuery
# !nvcc --version

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /bin/bash: line 0: cd: /usr/local/cuda/samples/1_Utilities/deviceQuery: No such file or directory
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Tue_Mar__8_18:18:20_PST_2022
# Cuda compilation tools, release 11.6, V11.6.124
# Build cuda_11.6.r11.6/compiler.31057947_0
# Mounted at /content/gdrive

# %% [markdown]
# ###Write, compile, run the CUDA code and visualize the result

# %%
# %cd /content/gdrive/MyDrive/Colab Notebooks/CS4835/Assignments/Assignment 3
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/CS4835/Assignments/Assignment 3

# %% [markdown]
# Compile the program:

# %%
# !nvcc -w -arch=sm_75 -o "./voronoi" "./voronoi.cu"

# %% [markdown]
# Run the program: `voronoi <width> <height> <sites>`

# %%
!"./voronoi"  550 783 10
# Out:
# Copying all sites from host to device...
# dimGrid: (22, 27)
# dimBlock: (25, 29)
# Resolution: 550x783
# Sites: 10

# %% [markdown]
# Visualize the result:

# %%
from IPython.display import display
from PIL import Image

display(Image.open("./out.ppm"))
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=550x783 at 0x7F87CC3B6AF0>
